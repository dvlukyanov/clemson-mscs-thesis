# %%
import sys
sys.path.insert(0, '../')
import os
import random
import math
from statistics import mean
import yaml
import pickle as pkl
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from model.model_factory import ModelFactory
from util.dataload import ImageDataset

# %%
class Server:
    def __init__(self, config):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
        self.config = config
        self.rng = random.Random()
        self.rng.seed(self.config['seed'])
        self.round = 0
        self.clients = [Client(self, idx, self.device) for idx in range(1, self.config['client']['qnt'] + 1)]
        self.model_types = list(set([client.model_type for client in self.clients]))
        self.models = {type: {'name': None, 'model': None} for type in self.model_types}
        self.accuracy = {}

    def train(self):
        rounds = math.ceil(self.config['server']['epochs'] / (self.config['client']['training']['epochs']))
        for round in range(1, rounds + 1):
            # chosen = self.rng.sample(range(1, self.config['client']['qnt'] + 1), self.config['client']['chosen'])
            # print(f'Chosen clients: {chosen}')
            # clients = [client for client in self.clients if client.id in chosen]
            clients = self.select_clients()
            print(f'Chosen clients: {[client.id for client in clients]}')
            for client in clients:
                client.train(self.models[client.model_type]['name'])
            self.models = {type: self.aggregate(clients, type) for type in self.models.keys()}
            self.models = {type: self.extract(clients, type) for type in self.models.keys()}
            accuracy = self.test()
            self.save_models()
            self.round = round
            epochs = self.round * self.config["client"]["training"]["epochs"]
            for type, acc in accuracy.items():
                if type not in self.accuracy:
                    self.accuracy[type] = {}
                self.accuracy[type][epochs] = acc
        print(self.accuracy)
            
    def select_clients(self):
        groups = {}
        for client in self.clients:
            if client.model_type not in groups:
                groups[client.model_type] = []
            groups[client.model_type].append(client)

        [self.rng.shuffle(group) for group in groups.values()]

        selected = []
        for _, group in groups.items():
            selected.append(self.rng.choice(group))
            if len(selected) == config['server']['knowledge_transfer']['client_qnt']:
                break
        return selected

    def aggregate(self, clients, model_type):
        states = [client.model.state_dict() for client in clients if client.model_type == model_type]
        if len(states) == 0:
            states = [client.model.state_dict() for client in self.clients if client.model_type == model_type]
        model = ModelFactory.create(model_type, self.device)
        state = {}
        for key in states[0].keys():
            state[key] = torch.mean(torch.stack([state[key].to(torch.float32) for state in states]), dim=0, keepdim=False)
        model.load_state_dict(state)
        model.eval()
        name = self.config['storage']['model']['name']['server'].format(model_type, self.round)
        print(f'Models for {model_type} are aggregated')
        return {'name': name, 'model': model}

    def extract(self, clients, model_type):
        random.seed(self.config['seed'])
        torch.manual_seed(self.config['seed'])
        torch.cuda.manual_seed(self.config['seed'])
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

        model = self.models[model_type]['model']

        # criterion = nn.CrossEntropyLoss()
        # optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.001)
        # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.1)
        optimizer = model.optimizer(model)
        scheduler = model.scheduler(optimizer)

        data_file = open(os.path.join(config['storage']['data']['path'], 'kt.pkl'), 'rb')
        data = pkl.load(data_file)

        # transform = transforms.Compose([
        #     transforms.ToTensor(),
        #     transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
        # ])
        
        train_dataset = ImageDataset(data['train'], config['seed'])
        test_dataset = ImageDataset(data['test'], config['seed'])

        # train_dataset = torchvision.datasets.CIFAR100(root=self.config['storage']['data']['path'], train=True, download=True, transform=transform)
        # test_dataset = torchvision.datasets.CIFAR100(root=self.config['storage']['data']['path'], train=False, download=True, transform=transform)

        trainloader = DataLoader(train_dataset, batch_size=self.config['server']['knowledge_transfer']['batch_size'], shuffle=False)
        testloader = DataLoader(test_dataset, batch_size=self.config['server']['knowledge_transfer']['batch_size'], shuffle=False)

        softmax_temperature = config['server']['knowledge_transfer']['temperature']
        soft_target_loss_weight = config['server']['knowledge_transfer']['soft_target_loss_weight']
        criterion_loss_weight = config['server']['knowledge_transfer']['criterion_loss_weight']

        criterion_kldl = torch.nn.KLDivLoss(reduction="batchmean")

        for epoch in range(config['server']['knowledge_transfer']['epochs']):
            running_loss = 0.0

            correct_predictions_train = 0
            total_samples_train = 0

            for i, data in enumerate(trainloader, 0):
                inputs, labels = data[0].to(self.device), data[1].to(self.device)
                
                optimizer.zero_grad()

                teacher_outputs = self.get_averaged_logits(list(map(lambda c: c.model, clients)), inputs)
                outputs = model(inputs)

                loss = (softmax_temperature ** 2) * criterion_kldl(
                    torch.nn.functional.log_softmax(
                        outputs / softmax_temperature, dim=1
                    ),
                    torch.nn.functional.softmax(
                        teacher_outputs / softmax_temperature,
                        dim=1,
                    ),
                )
                loss.backward()
                optimizer.step()

                _, predicted_train = torch.max(outputs, 1)
                total_samples_train += labels.size(0)
                correct_predictions_train += (predicted_train == labels).sum().item()

                running_loss += loss.item()

            accuracy_train = 100 * correct_predictions_train / total_samples_train

            correct_predictions_test = 0
            total_samples_test = 0
            with torch.no_grad():
                for data in testloader:
                    inputs, labels = data[0].to(self.device), data[1].to(self.device)
                    outputs = model(inputs)
                    _, predicted_test = torch.max(outputs, 1)
                    total_samples_test += labels.size(0)
                    correct_predictions_test += (predicted_test == labels).sum().item()

            accuracy_test = 100 * correct_predictions_test / total_samples_test

            print(f'KT: {model_type}. Epoch: {epoch + 1}. Loss: {running_loss / 100:.3f}. Train accuracy: {accuracy_train:.2f}%. Test accuracy: {accuracy_test:.2f}%')

            scheduler.step()

        return {'name': self.config['storage']['model']['name']['server'].format(model_type, self.round + 1), 'model': model}

    def get_averaged_logits(self, models, inputs):
        outputs = []
        for model in models:
            with torch.no_grad():
                _output = model(inputs)
                outputs.append(_output)
        avg = torch.mean(torch.stack(outputs, dim=0), dim=0, keepdim=False)
        return avg

    def test(self):
        result = {}
        for type, item in self.models.items():
            data_file = open(os.path.join(config['storage']['data']['path'], 'test.pkl'), 'rb')
            data = pkl.load(data_file)
            test_dataset = ImageDataset(data, self.config['seed'])
            testloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

            correct = 0
            total = 0
            with torch.no_grad():
                for i, data in enumerate(testloader, 0):
                    images, labels = data[0].to(self.device), data[1].to(self.device)
                    outputs = item['model'](images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
            print(f'Accuracy of {type} on the {total} test images at {self.round + 1} round: {100 * correct / total} %')
            accuracy = 100 * correct / total
            result[type] = accuracy
        return result

    def save_models(self):
        for type, item in self.models.items():
            model_name = item['name']
            model_path = os.path.join(self.config['storage']['model']['path'], model_name)
            Utils.save_model(item['model'], model_path)

class Client:
    def __init__(self, server, id, device):
        self.server = server
        self.id = id
        self.device = device
        self.model_type = self.server.config['client']['models'][self.id % len(self.server.config['client']['models'])]
        self.model = ModelFactory.create(self.model_type, self.device, self.server.config['seed'])
        self.model_name = self.save_model()

    def save_model(self):
        model_name = self.server.config['storage']['model']['name']['client'].format(self.server.round, self.id)
        model_path = os.path.join(self.server.config['storage']['model']['path'], model_name)
        Utils.save_model(self.model, model_path)
        return model_name

    def train(self, model_name=None):
        random.seed(self.server.config['seed'])
        torch.manual_seed(self.server.config['seed'])
        torch.cuda.manual_seed(self.server.config['seed'])
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

        if model_name:
            self.model = Utils.load_model(self.device, self.model_type, self.server.config['storage']['model']['path'] + '/' + model_name, self.server.config['seed'])

        criterion = nn.CrossEntropyLoss()
        # optimizer = optim.Adam(self.model.parameters(), lr=0.001, betas=(0.9, 0.99), eps=1e-08, weight_decay=1e-5)
        # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.1)
        optimizer = self.model.optimizer(self.model)
        scheduler = self.model.scheduler(optimizer)
        # optimizer = optim.Adam(self.model.parameters(), lr=0.0007, weight_decay=0.001)
        # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.11)

        data_file = open(os.path.join(self.server.config['storage']['data']['path'], f'partition_{self.id}.pkl'), 'rb')
        data = pkl.load(data_file)

        train_dataset = ImageDataset(data['train'], self.server.config['seed'])
        test_dataset = ImageDataset(data['test'], self.server.config['seed'])

        trainloader = DataLoader(train_dataset, batch_size=self.server.config['client']['training']['batch_size'], shuffle=False)
        testloader = DataLoader(test_dataset, batch_size=self.server.config['client']['training']['batch_size'], shuffle=False)

        for epoch in range(self.server.config['client']['training']['epochs']):
            running_loss = 0.0
            correct_predictions_train = 0
            total_samples_train = 0

            for _, data in enumerate(trainloader, 0):
                inputs, labels = data[0].to(self.device), data[1].to(self.device)

                optimizer.zero_grad()
                outputs = self.model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                _, predicted_train = torch.max(outputs, 1)
                total_samples_train += labels.size(0)
                correct_predictions_train += (predicted_train == labels).sum().item()

                running_loss += loss.item()

            accuracy_train = 100 * correct_predictions_train / total_samples_train

            correct_predictions_test = 0
            total_samples_test = 0
            with torch.no_grad():
                for data in testloader:
                    inputs, labels = data[0].to(self.device), data[1].to(self.device)
                    outputs = self.model(inputs)
                    _, predicted_test = torch.max(outputs, 1)
                    total_samples_test += labels.size(0)
                    correct_predictions_test += (predicted_test == labels).sum().item()

            accuracy_test = 100 * correct_predictions_test / total_samples_test

            print(f'Round: {self.server.round + 1}. Client: {self.id} ({self.model_type}). Epoch: {epoch + 1}. Loss: {running_loss / 100:.3f}. Train accuracy: {accuracy_train:.2f}%. Test accuracy: {accuracy_test:.2f}%')

            scheduler.step()


class Utils:

    @staticmethod
    def load_model(device, model_type, model_path, seed):
        model = ModelFactory.create(model_type, device, seed)
        model.load_state_dict(torch.load(model_path))
        model.eval()
        return model
    
    @staticmethod
    def save_model(model, model_path):
        torch.save(model.state_dict(), model_path)
        print(f'Model {model_path} saved')

    @staticmethod
    def test(device, model, batch_size, seed):
        data_file = open(os.path.join(config['storage']['data']['path'], 'test.pkl'), 'rb')
        data = pkl.load(data_file)
        test_dataset = ImageDataset(data, seed)
        testloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        correct = 0
        total = 0
        with torch.no_grad():
            for _, data in enumerate(testloader, 0):
                images, labels = data[0].to(device), data[1].to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        return [correct, total]

# %%
with open('feddf_config.yaml', 'r') as file:
        config = yaml.safe_load(file)

# %%
cloud = Server(config)
cloud.train()
# Out:
# Model ../storage/model/feddf/model_client_0_1.pt saved
# Model ../storage/model/feddf/model_client_0_2.pt saved
# Model ../storage/model/feddf/model_client_0_3.pt saved
# Model ../storage/model/feddf/model_client_0_4.pt saved
# Model ../storage/model/feddf/model_client_0_5.pt saved
# Model ../storage/model/feddf/model_client_0_6.pt saved
# Model ../storage/model/feddf/model_client_0_7.pt saved
# Model ../storage/model/feddf/model_client_0_8.pt saved
# Model ../storage/model/feddf/model_client_0_9.pt saved
# Model ../storage/model/feddf/model_client_0_10.pt saved
# Model ../storage/model/feddf/model_client_0_11.pt saved
# Model ../storage/model/feddf/model_client_0_12.pt saved
# Model ../storage/model/feddf/model_client_0_13.pt saved
# Model ../storage/model/feddf/model_client_0_14.pt saved
# Model ../storage/model/feddf/model_client_0_15.pt saved
# Model ../storage/model/feddf/model_client_0_16.pt saved
# Model ../storage/model/feddf/model_client_0_17.pt saved
# Model ../storage/model/feddf/model_client_0_18.pt saved
# Model ../storage/model/feddf/model_client_0_19.pt saved
# Model ../storage/model/feddf/model_client_0_20.pt saved
# Chosen clients: [4, 14, 12]
# Round: 1. Client: 4 (resnet). Epoch: 1. Loss: 0.675. Train accuracy: 22.75%. Test accuracy: 27.80%
# Round: 1. Client: 4 (resnet). Epoch: 2. Loss: 0.590. Train accuracy: 34.20%. Test accuracy: 33.40%
# Round: 1. Client: 4 (resnet). Epoch: 3. Loss: 0.548. Train accuracy: 39.00%. Test accuracy: 34.20%
# Round: 1. Client: 4 (resnet). Epoch: 4. Loss: 0.519. Train accuracy: 42.45%. Test accuracy: 37.00%
# Round: 1. Client: 4 (resnet). Epoch: 5. Loss: 0.492. Train accuracy: 45.90%. Test accuracy: 40.60%
# Round: 1. Client: 14 (simple_cnn). Epoch: 1. Loss: 0.567. Train accuracy: 38.15%. Test accuracy: 45.00%
# Round: 1. Client: 14 (simple_cnn). Epoch: 2. Loss: 0.410. Train accuracy: 55.35%. Test accuracy: 49.20%
# Round: 1. Client: 14 (simple_cnn). Epoch: 3. Loss: 0.280. Train accuracy: 73.75%. Test accuracy: 53.60%
# Round: 1. Client: 14 (simple_cnn). Epoch: 4. Loss: 0.231. Train accuracy: 80.75%. Test accuracy: 54.00%
# Round: 1. Client: 14 (simple_cnn). Epoch: 5. Loss: 0.196. Train accuracy: 85.95%. Test accuracy: 55.80%
# Round: 1. Client: 12 (mobilenetv2). Epoch: 1. Loss: 0.668. Train accuracy: 20.25%. Test accuracy: 27.80%
# Round: 1. Client: 12 (mobilenetv2). Epoch: 2. Loss: 0.562. Train accuracy: 33.75%. Test accuracy: 35.20%
# Round: 1. Client: 12 (mobilenetv2). Epoch: 3. Loss: 0.405. Train accuracy: 54.25%. Test accuracy: 38.40%
# Round: 1. Client: 12 (mobilenetv2). Epoch: 4. Loss: 0.295. Train accuracy: 69.75%. Test accuracy: 39.20%
# Round: 1. Client: 12 (mobilenetv2). Epoch: 5. Loss: 0.196. Train accuracy: 85.80%. Test accuracy: 39.20%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 6.666. Train accuracy: 21.86%. Test accuracy: 30.93%
# KT: simple_cnn. Epoch: 2. Loss: 0.384. Train accuracy: 33.18%. Test accuracy: 37.07%
# KT: simple_cnn. Epoch: 3. Loss: 0.261. Train accuracy: 37.41%. Test accuracy: 39.79%
# KT: simple_cnn. Epoch: 4. Loss: 0.239. Train accuracy: 39.50%. Test accuracy: 40.14%
# KT: simple_cnn. Epoch: 5. Loss: 0.221. Train accuracy: 40.50%. Test accuracy: 40.50%
# KT: simple_cnn. Epoch: 6. Loss: 0.218. Train accuracy: 40.96%. Test accuracy: 40.71%
# KT: simple_cnn. Epoch: 7. Loss: 0.216. Train accuracy: 40.86%. Test accuracy: 40.79%
# KT: simple_cnn. Epoch: 8. Loss: 0.215. Train accuracy: 41.02%. Test accuracy: 41.00%
# KT: simple_cnn. Epoch: 9. Loss: 0.215. Train accuracy: 41.00%. Test accuracy: 41.00%
# KT: simple_cnn. Epoch: 10. Loss: 0.215. Train accuracy: 41.00%. Test accuracy: 41.07%
# KT: resnet. Epoch: 1. Loss: 0.271. Train accuracy: 39.05%. Test accuracy: 42.07%
# KT: resnet. Epoch: 2. Loss: 0.191. Train accuracy: 42.18%. Test accuracy: 41.64%
# KT: resnet. Epoch: 3. Loss: 0.181. Train accuracy: 42.96%. Test accuracy: 43.21%
# KT: resnet. Epoch: 4. Loss: 0.169. Train accuracy: 44.04%. Test accuracy: 44.29%
# KT: resnet. Epoch: 5. Loss: 0.160. Train accuracy: 44.71%. Test accuracy: 44.50%
# KT: resnet. Epoch: 6. Loss: 0.153. Train accuracy: 45.16%. Test accuracy: 45.21%
# KT: resnet. Epoch: 7. Loss: 0.148. Train accuracy: 45.00%. Test accuracy: 46.07%
# KT: resnet. Epoch: 8. Loss: 0.143. Train accuracy: 45.41%. Test accuracy: 46.36%
# KT: resnet. Epoch: 9. Loss: 0.140. Train accuracy: 45.80%. Test accuracy: 47.00%
# KT: resnet. Epoch: 10. Loss: 0.136. Train accuracy: 46.16%. Test accuracy: 47.36%
# KT: mobilenetv2. Epoch: 1. Loss: 0.713. Train accuracy: 22.71%. Test accuracy: 32.14%
# KT: mobilenetv2. Epoch: 2. Loss: 0.300. Train accuracy: 36.04%. Test accuracy: 39.00%
# KT: mobilenetv2. Epoch: 3. Loss: 0.171. Train accuracy: 41.95%. Test accuracy: 42.21%
# KT: mobilenetv2. Epoch: 4. Loss: 0.153. Train accuracy: 42.77%. Test accuracy: 42.79%
# KT: mobilenetv2. Epoch: 5. Loss: 0.140. Train accuracy: 43.29%. Test accuracy: 42.57%
# KT: mobilenetv2. Epoch: 6. Loss: 0.138. Train accuracy: 43.18%. Test accuracy: 42.71%
# KT: mobilenetv2. Epoch: 7. Loss: 0.136. Train accuracy: 43.36%. Test accuracy: 42.43%
# KT: mobilenetv2. Epoch: 8. Loss: 0.136. Train accuracy: 43.09%. Test accuracy: 42.29%
# KT: mobilenetv2. Epoch: 9. Loss: 0.136. Train accuracy: 43.20%. Test accuracy: 42.29%
# KT: mobilenetv2. Epoch: 10. Loss: 0.135. Train accuracy: 43.20%. Test accuracy: 42.29%
# Accuracy of simple_cnn on the 3000 test images at 1 round: 40.8 %
# Accuracy of resnet on the 3000 test images at 1 round: 46.333333333333336 %
# Accuracy of mobilenetv2 on the 3000 test images at 1 round: 44.2 %
# Model ../storage/model/feddf/model_server_simple_cnn_1.pt saved
# Model ../storage/model/feddf/model_server_resnet_1.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_1.pt saved
# Chosen clients: [16, 11, 12]
# Round: 2. Client: 16 (resnet). Epoch: 1. Loss: 0.489. Train accuracy: 43.05%. Test accuracy: 40.00%
# Round: 2. Client: 16 (resnet). Epoch: 2. Loss: 0.466. Train accuracy: 45.10%. Test accuracy: 44.20%
# Round: 2. Client: 16 (resnet). Epoch: 3. Loss: 0.457. Train accuracy: 46.80%. Test accuracy: 43.80%
# Round: 2. Client: 16 (resnet). Epoch: 4. Loss: 0.449. Train accuracy: 47.65%. Test accuracy: 44.40%
# Round: 2. Client: 16 (resnet). Epoch: 5. Loss: 0.438. Train accuracy: 49.10%. Test accuracy: 45.60%
# Round: 2. Client: 11 (simple_cnn). Epoch: 1. Loss: 0.624. Train accuracy: 28.70%. Test accuracy: 35.00%
# Round: 2. Client: 11 (simple_cnn). Epoch: 2. Loss: 0.552. Train accuracy: 35.35%. Test accuracy: 34.60%
# Round: 2. Client: 11 (simple_cnn). Epoch: 3. Loss: 0.454. Train accuracy: 47.15%. Test accuracy: 43.40%
# Round: 2. Client: 11 (simple_cnn). Epoch: 4. Loss: 0.411. Train accuracy: 52.70%. Test accuracy: 44.00%
# Round: 2. Client: 11 (simple_cnn). Epoch: 5. Loss: 0.376. Train accuracy: 56.45%. Test accuracy: 43.40%
# Round: 2. Client: 12 (mobilenetv2). Epoch: 1. Loss: 0.773. Train accuracy: 22.05%. Test accuracy: 24.40%
# Round: 2. Client: 12 (mobilenetv2). Epoch: 2. Loss: 0.573. Train accuracy: 29.35%. Test accuracy: 32.40%
# Round: 2. Client: 12 (mobilenetv2). Epoch: 3. Loss: 0.515. Train accuracy: 37.90%. Test accuracy: 37.80%
# Round: 2. Client: 12 (mobilenetv2). Epoch: 4. Loss: 0.488. Train accuracy: 41.20%. Test accuracy: 36.00%
# Round: 2. Client: 12 (mobilenetv2). Epoch: 5. Loss: 0.478. Train accuracy: 41.70%. Test accuracy: 39.60%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.207. Train accuracy: 39.09%. Test accuracy: 45.00%
# KT: simple_cnn. Epoch: 2. Loss: 0.090. Train accuracy: 42.82%. Test accuracy: 45.21%
# KT: simple_cnn. Epoch: 3. Loss: 0.057. Train accuracy: 44.93%. Test accuracy: 45.21%
# KT: simple_cnn. Epoch: 4. Loss: 0.050. Train accuracy: 45.16%. Test accuracy: 45.86%
# KT: simple_cnn. Epoch: 5. Loss: 0.044. Train accuracy: 45.39%. Test accuracy: 46.43%
# KT: simple_cnn. Epoch: 6. Loss: 0.043. Train accuracy: 45.57%. Test accuracy: 46.50%
# KT: simple_cnn. Epoch: 7. Loss: 0.042. Train accuracy: 45.32%. Test accuracy: 46.57%
# KT: simple_cnn. Epoch: 8. Loss: 0.042. Train accuracy: 45.38%. Test accuracy: 46.43%
# KT: simple_cnn. Epoch: 9. Loss: 0.042. Train accuracy: 45.41%. Test accuracy: 46.43%
# KT: simple_cnn. Epoch: 10. Loss: 0.042. Train accuracy: 45.39%. Test accuracy: 46.43%
# KT: resnet. Epoch: 1. Loss: 0.114. Train accuracy: 46.66%. Test accuracy: 48.14%
# KT: resnet. Epoch: 2. Loss: 0.075. Train accuracy: 47.14%. Test accuracy: 48.36%
# KT: resnet. Epoch: 3. Loss: 0.071. Train accuracy: 46.66%. Test accuracy: 48.57%
# KT: resnet. Epoch: 4. Loss: 0.067. Train accuracy: 46.89%. Test accuracy: 48.43%
# KT: resnet. Epoch: 5. Loss: 0.063. Train accuracy: 46.50%. Test accuracy: 48.07%
# KT: resnet. Epoch: 6. Loss: 0.061. Train accuracy: 46.21%. Test accuracy: 47.86%
# KT: resnet. Epoch: 7. Loss: 0.059. Train accuracy: 46.30%. Test accuracy: 47.86%
# KT: resnet. Epoch: 8. Loss: 0.058. Train accuracy: 46.45%. Test accuracy: 47.71%
# KT: resnet. Epoch: 9. Loss: 0.058. Train accuracy: 46.45%. Test accuracy: 47.64%
# KT: resnet. Epoch: 10. Loss: 0.057. Train accuracy: 46.61%. Test accuracy: 47.71%
# KT: mobilenetv2. Epoch: 1. Loss: 0.375. Train accuracy: 33.04%. Test accuracy: 39.21%
# KT: mobilenetv2. Epoch: 2. Loss: 0.133. Train accuracy: 39.25%. Test accuracy: 42.21%
# KT: mobilenetv2. Epoch: 3. Loss: 0.088. Train accuracy: 41.02%. Test accuracy: 42.57%
# KT: mobilenetv2. Epoch: 4. Loss: 0.082. Train accuracy: 41.43%. Test accuracy: 42.79%
# KT: mobilenetv2. Epoch: 5. Loss: 0.078. Train accuracy: 41.54%. Test accuracy: 43.43%
# KT: mobilenetv2. Epoch: 6. Loss: 0.077. Train accuracy: 41.61%. Test accuracy: 43.43%
# KT: mobilenetv2. Epoch: 7. Loss: 0.076. Train accuracy: 41.64%. Test accuracy: 43.43%
# KT: mobilenetv2. Epoch: 8. Loss: 0.076. Train accuracy: 41.50%. Test accuracy: 43.50%
# KT: mobilenetv2. Epoch: 9. Loss: 0.076. Train accuracy: 41.43%. Test accuracy: 43.50%
# KT: mobilenetv2. Epoch: 10. Loss: 0.076. Train accuracy: 41.45%. Test accuracy: 43.43%
# Accuracy of simple_cnn on the 3000 test images at 2 round: 45.03333333333333 %
# Accuracy of resnet on the 3000 test images at 2 round: 47.266666666666666 %
# Accuracy of mobilenetv2 on the 3000 test images at 2 round: 43.43333333333333 %
# Model ../storage/model/feddf/model_server_simple_cnn_2.pt saved
# Model ../storage/model/feddf/model_server_resnet_2.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_2.pt saved
# Chosen clients: [7, 17, 9]
# Round: 3. Client: 7 (resnet). Epoch: 1. Loss: 0.497. Train accuracy: 42.50%. Test accuracy: 44.60%
# Round: 3. Client: 7 (resnet). Epoch: 2. Loss: 0.475. Train accuracy: 44.80%. Test accuracy: 47.80%
# Round: 3. Client: 7 (resnet). Epoch: 3. Loss: 0.463. Train accuracy: 45.80%. Test accuracy: 47.60%
# Round: 3. Client: 7 (resnet). Epoch: 4. Loss: 0.451. Train accuracy: 46.30%. Test accuracy: 46.00%
# Round: 3. Client: 7 (resnet). Epoch: 5. Loss: 0.441. Train accuracy: 47.45%. Test accuracy: 46.00%
# Round: 3. Client: 17 (simple_cnn). Epoch: 1. Loss: 0.550. Train accuracy: 37.40%. Test accuracy: 42.60%
# Round: 3. Client: 17 (simple_cnn). Epoch: 2. Loss: 0.449. Train accuracy: 46.10%. Test accuracy: 42.20%
# Round: 3. Client: 17 (simple_cnn). Epoch: 3. Loss: 0.379. Train accuracy: 55.55%. Test accuracy: 47.00%
# Round: 3. Client: 17 (simple_cnn). Epoch: 4. Loss: 0.342. Train accuracy: 60.30%. Test accuracy: 47.80%
# Round: 3. Client: 17 (simple_cnn). Epoch: 5. Loss: 0.317. Train accuracy: 63.55%. Test accuracy: 48.00%
# Round: 3. Client: 9 (mobilenetv2). Epoch: 1. Loss: 0.664. Train accuracy: 27.20%. Test accuracy: 32.20%
# Round: 3. Client: 9 (mobilenetv2). Epoch: 2. Loss: 0.541. Train accuracy: 36.00%. Test accuracy: 35.40%
# Round: 3. Client: 9 (mobilenetv2). Epoch: 3. Loss: 0.502. Train accuracy: 42.25%. Test accuracy: 41.00%
# Round: 3. Client: 9 (mobilenetv2). Epoch: 4. Loss: 0.472. Train accuracy: 43.85%. Test accuracy: 40.40%
# Round: 3. Client: 9 (mobilenetv2). Epoch: 5. Loss: 0.460. Train accuracy: 45.90%. Test accuracy: 40.40%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.182. Train accuracy: 44.04%. Test accuracy: 48.64%
# KT: simple_cnn. Epoch: 2. Loss: 0.062. Train accuracy: 47.36%. Test accuracy: 49.36%
# KT: simple_cnn. Epoch: 3. Loss: 0.035. Train accuracy: 48.48%. Test accuracy: 48.50%
# KT: simple_cnn. Epoch: 4. Loss: 0.031. Train accuracy: 48.52%. Test accuracy: 48.86%
# KT: simple_cnn. Epoch: 5. Loss: 0.027. Train accuracy: 48.57%. Test accuracy: 49.07%
# KT: simple_cnn. Epoch: 6. Loss: 0.027. Train accuracy: 48.64%. Test accuracy: 49.07%
# KT: simple_cnn. Epoch: 7. Loss: 0.026. Train accuracy: 48.46%. Test accuracy: 49.14%
# KT: simple_cnn. Epoch: 8. Loss: 0.026. Train accuracy: 48.45%. Test accuracy: 49.14%
# KT: simple_cnn. Epoch: 9. Loss: 0.026. Train accuracy: 48.46%. Test accuracy: 49.21%
# KT: simple_cnn. Epoch: 10. Loss: 0.026. Train accuracy: 48.46%. Test accuracy: 49.21%
# KT: resnet. Epoch: 1. Loss: 0.107. Train accuracy: 48.27%. Test accuracy: 49.86%
# KT: resnet. Epoch: 2. Loss: 0.070. Train accuracy: 48.68%. Test accuracy: 49.71%
# KT: resnet. Epoch: 3. Loss: 0.068. Train accuracy: 48.59%. Test accuracy: 49.29%
# KT: resnet. Epoch: 4. Loss: 0.065. Train accuracy: 48.79%. Test accuracy: 49.57%
# KT: resnet. Epoch: 5. Loss: 0.063. Train accuracy: 48.64%. Test accuracy: 49.43%
# KT: resnet. Epoch: 6. Loss: 0.062. Train accuracy: 48.75%. Test accuracy: 49.07%
# KT: resnet. Epoch: 7. Loss: 0.061. Train accuracy: 48.68%. Test accuracy: 48.86%
# KT: resnet. Epoch: 8. Loss: 0.061. Train accuracy: 48.62%. Test accuracy: 48.79%
# KT: resnet. Epoch: 9. Loss: 0.062. Train accuracy: 48.32%. Test accuracy: 48.86%
# KT: resnet. Epoch: 10. Loss: 0.064. Train accuracy: 48.20%. Test accuracy: 48.86%
# KT: mobilenetv2. Epoch: 1. Loss: 0.654. Train accuracy: 31.32%. Test accuracy: 39.71%
# KT: mobilenetv2. Epoch: 2. Loss: 0.169. Train accuracy: 39.61%. Test accuracy: 41.79%
# KT: mobilenetv2. Epoch: 3. Loss: 0.115. Train accuracy: 42.64%. Test accuracy: 42.57%
# KT: mobilenetv2. Epoch: 4. Loss: 0.108. Train accuracy: 42.54%. Test accuracy: 43.21%
# KT: mobilenetv2. Epoch: 5. Loss: 0.104. Train accuracy: 42.48%. Test accuracy: 42.86%
# KT: mobilenetv2. Epoch: 6. Loss: 0.103. Train accuracy: 42.55%. Test accuracy: 43.07%
# KT: mobilenetv2. Epoch: 7. Loss: 0.102. Train accuracy: 42.48%. Test accuracy: 43.07%
# KT: mobilenetv2. Epoch: 8. Loss: 0.102. Train accuracy: 42.57%. Test accuracy: 43.21%
# KT: mobilenetv2. Epoch: 9. Loss: 0.102. Train accuracy: 42.61%. Test accuracy: 43.14%
# KT: mobilenetv2. Epoch: 10. Loss: 0.102. Train accuracy: 42.57%. Test accuracy: 43.14%
# Accuracy of simple_cnn on the 3000 test images at 3 round: 47.46666666666667 %
# Accuracy of resnet on the 3000 test images at 3 round: 48.13333333333333 %
# Accuracy of mobilenetv2 on the 3000 test images at 3 round: 43.36666666666667 %
# Model ../storage/model/feddf/model_server_simple_cnn_3.pt saved
# Model ../storage/model/feddf/model_server_resnet_3.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_3.pt saved
# Chosen clients: [7, 17, 12]
# Round: 4. Client: 7 (resnet). Epoch: 1. Loss: 0.466. Train accuracy: 45.75%. Test accuracy: 46.20%
# Round: 4. Client: 7 (resnet). Epoch: 2. Loss: 0.445. Train accuracy: 48.75%. Test accuracy: 46.40%
# Round: 4. Client: 7 (resnet). Epoch: 3. Loss: 0.436. Train accuracy: 49.35%. Test accuracy: 50.60%
# Round: 4. Client: 7 (resnet). Epoch: 4. Loss: 0.428. Train accuracy: 49.20%. Test accuracy: 49.20%
# Round: 4. Client: 7 (resnet). Epoch: 5. Loss: 0.421. Train accuracy: 49.30%. Test accuracy: 48.20%
# Round: 4. Client: 17 (simple_cnn). Epoch: 1. Loss: 0.469. Train accuracy: 47.00%. Test accuracy: 44.00%
# Round: 4. Client: 17 (simple_cnn). Epoch: 2. Loss: 0.382. Train accuracy: 54.75%. Test accuracy: 42.60%
# Round: 4. Client: 17 (simple_cnn). Epoch: 3. Loss: 0.320. Train accuracy: 63.15%. Test accuracy: 46.60%
# Round: 4. Client: 17 (simple_cnn). Epoch: 4. Loss: 0.274. Train accuracy: 69.35%. Test accuracy: 47.80%
# Round: 4. Client: 17 (simple_cnn). Epoch: 5. Loss: 0.250. Train accuracy: 72.25%. Test accuracy: 49.80%
# Round: 4. Client: 12 (mobilenetv2). Epoch: 1. Loss: 0.615. Train accuracy: 30.90%. Test accuracy: 31.60%
# Round: 4. Client: 12 (mobilenetv2). Epoch: 2. Loss: 0.515. Train accuracy: 38.25%. Test accuracy: 35.20%
# Round: 4. Client: 12 (mobilenetv2). Epoch: 3. Loss: 0.461. Train accuracy: 45.90%. Test accuracy: 37.40%
# Round: 4. Client: 12 (mobilenetv2). Epoch: 4. Loss: 0.444. Train accuracy: 49.00%. Test accuracy: 39.00%
# Round: 4. Client: 12 (mobilenetv2). Epoch: 5. Loss: 0.436. Train accuracy: 49.85%. Test accuracy: 39.60%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.144. Train accuracy: 48.11%. Test accuracy: 50.36%
# KT: simple_cnn. Epoch: 2. Loss: 0.060. Train accuracy: 49.59%. Test accuracy: 51.00%
# KT: simple_cnn. Epoch: 3. Loss: 0.035. Train accuracy: 50.61%. Test accuracy: 51.14%
# KT: simple_cnn. Epoch: 4. Loss: 0.030. Train accuracy: 50.66%. Test accuracy: 50.86%
# KT: simple_cnn. Epoch: 5. Loss: 0.026. Train accuracy: 50.82%. Test accuracy: 51.07%
# KT: simple_cnn. Epoch: 6. Loss: 0.026. Train accuracy: 50.77%. Test accuracy: 51.29%
# KT: simple_cnn. Epoch: 7. Loss: 0.025. Train accuracy: 50.88%. Test accuracy: 51.36%
# KT: simple_cnn. Epoch: 8. Loss: 0.025. Train accuracy: 50.95%. Test accuracy: 51.21%
# KT: simple_cnn. Epoch: 9. Loss: 0.025. Train accuracy: 50.88%. Test accuracy: 51.21%
# KT: simple_cnn. Epoch: 10. Loss: 0.025. Train accuracy: 50.86%. Test accuracy: 51.21%
# KT: resnet. Epoch: 1. Loss: 0.114. Train accuracy: 50.27%. Test accuracy: 52.14%
# KT: resnet. Epoch: 2. Loss: 0.087. Train accuracy: 50.27%. Test accuracy: 51.71%
# KT: resnet. Epoch: 3. Loss: 0.084. Train accuracy: 50.21%. Test accuracy: 51.50%
# KT: resnet. Epoch: 4. Loss: 0.081. Train accuracy: 50.36%. Test accuracy: 51.21%
# KT: resnet. Epoch: 5. Loss: 0.079. Train accuracy: 50.48%. Test accuracy: 51.21%
# KT: resnet. Epoch: 6. Loss: 0.077. Train accuracy: 50.70%. Test accuracy: 51.29%
# KT: resnet. Epoch: 7. Loss: 0.075. Train accuracy: 50.70%. Test accuracy: 51.14%
# KT: resnet. Epoch: 8. Loss: 0.074. Train accuracy: 50.91%. Test accuracy: 51.29%
# KT: resnet. Epoch: 9. Loss: 0.072. Train accuracy: 50.93%. Test accuracy: 51.36%
# KT: resnet. Epoch: 10. Loss: 0.071. Train accuracy: 50.95%. Test accuracy: 51.43%
# KT: mobilenetv2. Epoch: 1. Loss: 0.402. Train accuracy: 37.88%. Test accuracy: 41.50%
# KT: mobilenetv2. Epoch: 2. Loss: 0.166. Train accuracy: 43.46%. Test accuracy: 43.29%
# KT: mobilenetv2. Epoch: 3. Loss: 0.123. Train accuracy: 44.93%. Test accuracy: 45.00%
# KT: mobilenetv2. Epoch: 4. Loss: 0.117. Train accuracy: 45.21%. Test accuracy: 45.21%
# KT: mobilenetv2. Epoch: 5. Loss: 0.113. Train accuracy: 45.18%. Test accuracy: 45.21%
# KT: mobilenetv2. Epoch: 6. Loss: 0.112. Train accuracy: 45.34%. Test accuracy: 45.36%
# KT: mobilenetv2. Epoch: 7. Loss: 0.111. Train accuracy: 45.54%. Test accuracy: 45.36%
# KT: mobilenetv2. Epoch: 8. Loss: 0.111. Train accuracy: 45.50%. Test accuracy: 45.36%
# KT: mobilenetv2. Epoch: 9. Loss: 0.111. Train accuracy: 45.55%. Test accuracy: 45.29%
# KT: mobilenetv2. Epoch: 10. Loss: 0.111. Train accuracy: 45.57%. Test accuracy: 45.21%
# Accuracy of simple_cnn on the 3000 test images at 4 round: 50.4 %
# Accuracy of resnet on the 3000 test images at 4 round: 50.6 %
# Accuracy of mobilenetv2 on the 3000 test images at 4 round: 46.53333333333333 %
# Model ../storage/model/feddf/model_server_simple_cnn_4.pt saved
# Model ../storage/model/feddf/model_server_resnet_4.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_4.pt saved
# Chosen clients: [13, 20, 15]
# Round: 5. Client: 13 (resnet). Epoch: 1. Loss: 0.472. Train accuracy: 44.40%. Test accuracy: 50.00%
# Round: 5. Client: 13 (resnet). Epoch: 2. Loss: 0.465. Train accuracy: 46.45%. Test accuracy: 51.80%
# Round: 5. Client: 13 (resnet). Epoch: 3. Loss: 0.451. Train accuracy: 48.30%. Test accuracy: 48.80%
# Round: 5. Client: 13 (resnet). Epoch: 4. Loss: 0.441. Train accuracy: 49.25%. Test accuracy: 49.60%
# Round: 5. Client: 13 (resnet). Epoch: 5. Loss: 0.430. Train accuracy: 50.40%. Test accuracy: 49.40%
# Round: 5. Client: 20 (simple_cnn). Epoch: 1. Loss: 0.500. Train accuracy: 43.90%. Test accuracy: 40.20%
# Round: 5. Client: 20 (simple_cnn). Epoch: 2. Loss: 0.412. Train accuracy: 50.45%. Test accuracy: 42.00%
# Round: 5. Client: 20 (simple_cnn). Epoch: 3. Loss: 0.322. Train accuracy: 62.50%. Test accuracy: 48.40%
# Round: 5. Client: 20 (simple_cnn). Epoch: 4. Loss: 0.288. Train accuracy: 67.20%. Test accuracy: 48.40%
# Round: 5. Client: 20 (simple_cnn). Epoch: 5. Loss: 0.266. Train accuracy: 70.35%. Test accuracy: 47.80%
# Round: 5. Client: 15 (mobilenetv2). Epoch: 1. Loss: 0.558. Train accuracy: 37.25%. Test accuracy: 40.60%
# Round: 5. Client: 15 (mobilenetv2). Epoch: 2. Loss: 0.488. Train accuracy: 43.10%. Test accuracy: 42.00%
# Round: 5. Client: 15 (mobilenetv2). Epoch: 3. Loss: 0.443. Train accuracy: 47.30%. Test accuracy: 43.80%
# Round: 5. Client: 15 (mobilenetv2). Epoch: 4. Loss: 0.427. Train accuracy: 49.35%. Test accuracy: 43.80%
# Round: 5. Client: 15 (mobilenetv2). Epoch: 5. Loss: 0.417. Train accuracy: 51.45%. Test accuracy: 44.40%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.126. Train accuracy: 49.43%. Test accuracy: 52.43%
# KT: simple_cnn. Epoch: 2. Loss: 0.047. Train accuracy: 51.30%. Test accuracy: 52.71%
# KT: simple_cnn. Epoch: 3. Loss: 0.027. Train accuracy: 52.14%. Test accuracy: 53.14%
# KT: simple_cnn. Epoch: 4. Loss: 0.023. Train accuracy: 52.27%. Test accuracy: 53.43%
# KT: simple_cnn. Epoch: 5. Loss: 0.020. Train accuracy: 52.25%. Test accuracy: 53.29%
# KT: simple_cnn. Epoch: 6. Loss: 0.020. Train accuracy: 52.39%. Test accuracy: 53.14%
# KT: simple_cnn. Epoch: 7. Loss: 0.019. Train accuracy: 52.23%. Test accuracy: 53.07%
# KT: simple_cnn. Epoch: 8. Loss: 0.019. Train accuracy: 52.36%. Test accuracy: 53.14%
# KT: simple_cnn. Epoch: 9. Loss: 0.019. Train accuracy: 52.32%. Test accuracy: 53.07%
# KT: simple_cnn. Epoch: 10. Loss: 0.019. Train accuracy: 52.39%. Test accuracy: 53.07%
# KT: resnet. Epoch: 1. Loss: 0.092. Train accuracy: 51.20%. Test accuracy: 53.64%
# KT: resnet. Epoch: 2. Loss: 0.067. Train accuracy: 52.00%. Test accuracy: 53.50%
# KT: resnet. Epoch: 3. Loss: 0.064. Train accuracy: 51.68%. Test accuracy: 53.43%
# KT: resnet. Epoch: 4. Loss: 0.062. Train accuracy: 51.89%. Test accuracy: 53.14%
# KT: resnet. Epoch: 5. Loss: 0.060. Train accuracy: 52.21%. Test accuracy: 53.21%
# KT: resnet. Epoch: 6. Loss: 0.059. Train accuracy: 52.11%. Test accuracy: 53.21%
# KT: resnet. Epoch: 7. Loss: 0.057. Train accuracy: 52.02%. Test accuracy: 53.57%
# KT: resnet. Epoch: 8. Loss: 0.056. Train accuracy: 52.18%. Test accuracy: 53.79%
# KT: resnet. Epoch: 9. Loss: 0.055. Train accuracy: 52.16%. Test accuracy: 53.79%
# KT: resnet. Epoch: 10. Loss: 0.054. Train accuracy: 52.14%. Test accuracy: 53.86%
# KT: mobilenetv2. Epoch: 1. Loss: 0.212. Train accuracy: 44.00%. Test accuracy: 45.86%
# KT: mobilenetv2. Epoch: 2. Loss: 0.124. Train accuracy: 46.88%. Test accuracy: 46.93%
# KT: mobilenetv2. Epoch: 3. Loss: 0.081. Train accuracy: 47.79%. Test accuracy: 48.57%
# KT: mobilenetv2. Epoch: 4. Loss: 0.076. Train accuracy: 48.18%. Test accuracy: 48.71%
# KT: mobilenetv2. Epoch: 5. Loss: 0.072. Train accuracy: 48.29%. Test accuracy: 48.29%
# KT: mobilenetv2. Epoch: 6. Loss: 0.071. Train accuracy: 48.46%. Test accuracy: 48.21%
# KT: mobilenetv2. Epoch: 7. Loss: 0.071. Train accuracy: 48.32%. Test accuracy: 48.21%
# KT: mobilenetv2. Epoch: 8. Loss: 0.071. Train accuracy: 48.30%. Test accuracy: 48.07%
# KT: mobilenetv2. Epoch: 9. Loss: 0.070. Train accuracy: 48.34%. Test accuracy: 48.07%
# KT: mobilenetv2. Epoch: 10. Loss: 0.070. Train accuracy: 48.34%. Test accuracy: 48.07%
# Accuracy of simple_cnn on the 3000 test images at 5 round: 52.6 %
# Accuracy of resnet on the 3000 test images at 5 round: 52.5 %
# Accuracy of mobilenetv2 on the 3000 test images at 5 round: 48.6 %
# Model ../storage/model/feddf/model_server_simple_cnn_5.pt saved
# Model ../storage/model/feddf/model_server_resnet_5.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_5.pt saved
# Chosen clients: [1, 2, 9]
# Round: 6. Client: 1 (resnet). Epoch: 1. Loss: 0.439. Train accuracy: 48.60%. Test accuracy: 49.00%
# Round: 6. Client: 1 (resnet). Epoch: 2. Loss: 0.423. Train accuracy: 49.20%. Test accuracy: 51.20%
# Round: 6. Client: 1 (resnet). Epoch: 3. Loss: 0.414. Train accuracy: 51.45%. Test accuracy: 51.00%
# Round: 6. Client: 1 (resnet). Epoch: 4. Loss: 0.406. Train accuracy: 52.15%. Test accuracy: 50.80%
# Round: 6. Client: 1 (resnet). Epoch: 5. Loss: 0.397. Train accuracy: 53.85%. Test accuracy: 51.60%
# Round: 6. Client: 2 (simple_cnn). Epoch: 1. Loss: 0.461. Train accuracy: 48.05%. Test accuracy: 46.60%
# Round: 6. Client: 2 (simple_cnn). Epoch: 2. Loss: 0.370. Train accuracy: 56.50%. Test accuracy: 48.40%
# Round: 6. Client: 2 (simple_cnn). Epoch: 3. Loss: 0.302. Train accuracy: 66.15%. Test accuracy: 54.00%
# Round: 6. Client: 2 (simple_cnn). Epoch: 4. Loss: 0.254. Train accuracy: 71.90%. Test accuracy: 54.40%
# Round: 6. Client: 2 (simple_cnn). Epoch: 5. Loss: 0.230. Train accuracy: 74.45%. Test accuracy: 54.00%
# Round: 6. Client: 9 (mobilenetv2). Epoch: 1. Loss: 0.510. Train accuracy: 41.35%. Test accuracy: 43.80%
# Round: 6. Client: 9 (mobilenetv2). Epoch: 2. Loss: 0.471. Train accuracy: 44.65%. Test accuracy: 42.40%
# Round: 6. Client: 9 (mobilenetv2). Epoch: 3. Loss: 0.442. Train accuracy: 48.80%. Test accuracy: 49.60%
# Round: 6. Client: 9 (mobilenetv2). Epoch: 4. Loss: 0.412. Train accuracy: 51.80%. Test accuracy: 48.80%
# Round: 6. Client: 9 (mobilenetv2). Epoch: 5. Loss: 0.403. Train accuracy: 53.10%. Test accuracy: 49.40%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.121. Train accuracy: 52.55%. Test accuracy: 55.07%
# KT: simple_cnn. Epoch: 2. Loss: 0.049. Train accuracy: 53.57%. Test accuracy: 53.64%
# KT: simple_cnn. Epoch: 3. Loss: 0.028. Train accuracy: 54.57%. Test accuracy: 55.21%
# KT: simple_cnn. Epoch: 4. Loss: 0.023. Train accuracy: 54.77%. Test accuracy: 55.21%
# KT: simple_cnn. Epoch: 5. Loss: 0.019. Train accuracy: 54.98%. Test accuracy: 55.50%
# KT: simple_cnn. Epoch: 6. Loss: 0.019. Train accuracy: 55.11%. Test accuracy: 55.43%
# KT: simple_cnn. Epoch: 7. Loss: 0.018. Train accuracy: 55.07%. Test accuracy: 55.36%
# KT: simple_cnn. Epoch: 8. Loss: 0.018. Train accuracy: 55.12%. Test accuracy: 55.36%
# KT: simple_cnn. Epoch: 9. Loss: 0.018. Train accuracy: 55.18%. Test accuracy: 55.36%
# KT: simple_cnn. Epoch: 10. Loss: 0.018. Train accuracy: 55.18%. Test accuracy: 55.36%
# KT: resnet. Epoch: 1. Loss: 0.101. Train accuracy: 52.70%. Test accuracy: 54.86%
# KT: resnet. Epoch: 2. Loss: 0.073. Train accuracy: 53.21%. Test accuracy: 54.36%
# KT: resnet. Epoch: 3. Loss: 0.068. Train accuracy: 53.55%. Test accuracy: 54.00%
# KT: resnet. Epoch: 4. Loss: 0.066. Train accuracy: 53.66%. Test accuracy: 54.71%
# KT: resnet. Epoch: 5. Loss: 0.065. Train accuracy: 53.41%. Test accuracy: 55.07%
# KT: resnet. Epoch: 6. Loss: 0.063. Train accuracy: 53.59%. Test accuracy: 54.71%
# KT: resnet. Epoch: 7. Loss: 0.061. Train accuracy: 53.38%. Test accuracy: 55.00%
# KT: resnet. Epoch: 8. Loss: 0.059. Train accuracy: 53.43%. Test accuracy: 55.36%
# KT: resnet. Epoch: 9. Loss: 0.058. Train accuracy: 53.54%. Test accuracy: 55.57%
# KT: resnet. Epoch: 10. Loss: 0.056. Train accuracy: 53.62%. Test accuracy: 55.86%
# KT: mobilenetv2. Epoch: 1. Loss: 0.256. Train accuracy: 45.48%. Test accuracy: 49.64%
# KT: mobilenetv2. Epoch: 2. Loss: 0.112. Train accuracy: 49.30%. Test accuracy: 50.29%
# KT: mobilenetv2. Epoch: 3. Loss: 0.085. Train accuracy: 49.82%. Test accuracy: 50.79%
# KT: mobilenetv2. Epoch: 4. Loss: 0.080. Train accuracy: 50.12%. Test accuracy: 50.64%
# KT: mobilenetv2. Epoch: 5. Loss: 0.078. Train accuracy: 50.43%. Test accuracy: 50.79%
# KT: mobilenetv2. Epoch: 6. Loss: 0.077. Train accuracy: 50.41%. Test accuracy: 50.79%
# KT: mobilenetv2. Epoch: 7. Loss: 0.077. Train accuracy: 50.43%. Test accuracy: 50.50%
# KT: mobilenetv2. Epoch: 8. Loss: 0.077. Train accuracy: 50.46%. Test accuracy: 50.50%
# KT: mobilenetv2. Epoch: 9. Loss: 0.077. Train accuracy: 50.46%. Test accuracy: 50.43%
# KT: mobilenetv2. Epoch: 10. Loss: 0.077. Train accuracy: 50.46%. Test accuracy: 50.43%
# Accuracy of simple_cnn on the 3000 test images at 6 round: 54.5 %
# Accuracy of resnet on the 3000 test images at 6 round: 54.266666666666666 %
# Accuracy of mobilenetv2 on the 3000 test images at 6 round: 50.833333333333336 %
# Model ../storage/model/feddf/model_server_simple_cnn_6.pt saved
# Model ../storage/model/feddf/model_server_resnet_6.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_6.pt saved
# Chosen clients: [10, 17, 18]
# Round: 7. Client: 10 (resnet). Epoch: 1. Loss: 0.415. Train accuracy: 52.45%. Test accuracy: 49.20%
# Round: 7. Client: 10 (resnet). Epoch: 2. Loss: 0.396. Train accuracy: 54.30%. Test accuracy: 48.60%
# Round: 7. Client: 10 (resnet). Epoch: 3. Loss: 0.388. Train accuracy: 54.90%. Test accuracy: 48.60%
# Round: 7. Client: 10 (resnet). Epoch: 4. Loss: 0.383. Train accuracy: 55.20%. Test accuracy: 50.00%
# Round: 7. Client: 10 (resnet). Epoch: 5. Loss: 0.374. Train accuracy: 56.40%. Test accuracy: 51.40%
# Round: 7. Client: 17 (simple_cnn). Epoch: 1. Loss: 0.422. Train accuracy: 51.35%. Test accuracy: 48.20%
# Round: 7. Client: 17 (simple_cnn). Epoch: 2. Loss: 0.342. Train accuracy: 60.45%. Test accuracy: 42.60%
# Round: 7. Client: 17 (simple_cnn). Epoch: 3. Loss: 0.283. Train accuracy: 66.95%. Test accuracy: 55.40%
# Round: 7. Client: 17 (simple_cnn). Epoch: 4. Loss: 0.233. Train accuracy: 74.35%. Test accuracy: 54.20%
# Round: 7. Client: 17 (simple_cnn). Epoch: 5. Loss: 0.212. Train accuracy: 77.35%. Test accuracy: 54.20%
# Round: 7. Client: 18 (mobilenetv2). Epoch: 1. Loss: 0.472. Train accuracy: 45.85%. Test accuracy: 49.40%
# Round: 7. Client: 18 (mobilenetv2). Epoch: 2. Loss: 0.444. Train accuracy: 48.50%. Test accuracy: 51.00%
# Round: 7. Client: 18 (mobilenetv2). Epoch: 3. Loss: 0.400. Train accuracy: 54.25%. Test accuracy: 50.60%
# Round: 7. Client: 18 (mobilenetv2). Epoch: 4. Loss: 0.384. Train accuracy: 56.35%. Test accuracy: 50.80%
# Round: 7. Client: 18 (mobilenetv2). Epoch: 5. Loss: 0.378. Train accuracy: 57.75%. Test accuracy: 51.80%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.106. Train accuracy: 54.18%. Test accuracy: 55.43%
# KT: simple_cnn. Epoch: 2. Loss: 0.060. Train accuracy: 55.50%. Test accuracy: 53.71%
# KT: simple_cnn. Epoch: 3. Loss: 0.033. Train accuracy: 56.39%. Test accuracy: 56.71%
# KT: simple_cnn. Epoch: 4. Loss: 0.024. Train accuracy: 56.71%. Test accuracy: 56.64%
# KT: simple_cnn. Epoch: 5. Loss: 0.021. Train accuracy: 57.21%. Test accuracy: 56.50%
# KT: simple_cnn. Epoch: 6. Loss: 0.020. Train accuracy: 57.18%. Test accuracy: 56.50%
# KT: simple_cnn. Epoch: 7. Loss: 0.020. Train accuracy: 57.21%. Test accuracy: 56.79%
# KT: simple_cnn. Epoch: 8. Loss: 0.020. Train accuracy: 57.18%. Test accuracy: 56.79%
# KT: simple_cnn. Epoch: 9. Loss: 0.020. Train accuracy: 57.16%. Test accuracy: 56.79%
# KT: simple_cnn. Epoch: 10. Loss: 0.020. Train accuracy: 57.16%. Test accuracy: 56.71%
# KT: resnet. Epoch: 1. Loss: 0.116. Train accuracy: 53.48%. Test accuracy: 57.64%
# KT: resnet. Epoch: 2. Loss: 0.076. Train accuracy: 55.34%. Test accuracy: 58.14%
# KT: resnet. Epoch: 3. Loss: 0.073. Train accuracy: 55.46%. Test accuracy: 57.79%
# KT: resnet. Epoch: 4. Loss: 0.070. Train accuracy: 55.55%. Test accuracy: 57.93%
# KT: resnet. Epoch: 5. Loss: 0.067. Train accuracy: 55.59%. Test accuracy: 57.86%
# KT: resnet. Epoch: 6. Loss: 0.065. Train accuracy: 55.46%. Test accuracy: 57.93%
# KT: resnet. Epoch: 7. Loss: 0.063. Train accuracy: 55.55%. Test accuracy: 58.00%
# KT: resnet. Epoch: 8. Loss: 0.062. Train accuracy: 55.46%. Test accuracy: 58.21%
# KT: resnet. Epoch: 9. Loss: 0.061. Train accuracy: 55.48%. Test accuracy: 57.93%
# KT: resnet. Epoch: 10. Loss: 0.060. Train accuracy: 55.57%. Test accuracy: 58.00%
# KT: mobilenetv2. Epoch: 1. Loss: 0.223. Train accuracy: 49.64%. Test accuracy: 49.86%
# KT: mobilenetv2. Epoch: 2. Loss: 0.105. Train accuracy: 51.55%. Test accuracy: 50.79%
# KT: mobilenetv2. Epoch: 3. Loss: 0.081. Train accuracy: 52.30%. Test accuracy: 51.86%
# KT: mobilenetv2. Epoch: 4. Loss: 0.077. Train accuracy: 52.32%. Test accuracy: 52.21%
# KT: mobilenetv2. Epoch: 5. Loss: 0.074. Train accuracy: 52.14%. Test accuracy: 51.86%
# KT: mobilenetv2. Epoch: 6. Loss: 0.074. Train accuracy: 52.20%. Test accuracy: 51.71%
# KT: mobilenetv2. Epoch: 7. Loss: 0.073. Train accuracy: 52.29%. Test accuracy: 51.93%
# KT: mobilenetv2. Epoch: 8. Loss: 0.073. Train accuracy: 52.29%. Test accuracy: 51.93%
# KT: mobilenetv2. Epoch: 9. Loss: 0.073. Train accuracy: 52.34%. Test accuracy: 51.93%
# KT: mobilenetv2. Epoch: 10. Loss: 0.073. Train accuracy: 52.36%. Test accuracy: 51.93%
# Accuracy of simple_cnn on the 3000 test images at 7 round: 55.233333333333334 %
# Accuracy of resnet on the 3000 test images at 7 round: 55.833333333333336 %
# Accuracy of mobilenetv2 on the 3000 test images at 7 round: 51.6 %
# Model ../storage/model/feddf/model_server_simple_cnn_7.pt saved
# Model ../storage/model/feddf/model_server_resnet_7.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_7.pt saved
# Chosen clients: [4, 17, 12]
# Round: 8. Client: 4 (resnet). Epoch: 1. Loss: 0.414. Train accuracy: 51.30%. Test accuracy: 48.80%
# Round: 8. Client: 4 (resnet). Epoch: 2. Loss: 0.386. Train accuracy: 55.80%. Test accuracy: 50.80%
# Round: 8. Client: 4 (resnet). Epoch: 3. Loss: 0.375. Train accuracy: 56.40%. Test accuracy: 52.40%
# Round: 8. Client: 4 (resnet). Epoch: 4. Loss: 0.364. Train accuracy: 58.45%. Test accuracy: 54.00%
# Round: 8. Client: 4 (resnet). Epoch: 5. Loss: 0.355. Train accuracy: 59.55%. Test accuracy: 54.20%
# Round: 8. Client: 17 (simple_cnn). Epoch: 1. Loss: 0.347. Train accuracy: 59.20%. Test accuracy: 49.60%
# Round: 8. Client: 17 (simple_cnn). Epoch: 2. Loss: 0.262. Train accuracy: 69.45%. Test accuracy: 51.00%
# Round: 8. Client: 17 (simple_cnn). Epoch: 3. Loss: 0.190. Train accuracy: 79.25%. Test accuracy: 56.40%
# Round: 8. Client: 17 (simple_cnn). Epoch: 4. Loss: 0.153. Train accuracy: 84.70%. Test accuracy: 56.40%
# Round: 8. Client: 17 (simple_cnn). Epoch: 5. Loss: 0.135. Train accuracy: 86.80%. Test accuracy: 57.60%
# Round: 8. Client: 12 (mobilenetv2). Epoch: 1. Loss: 0.473. Train accuracy: 45.75%. Test accuracy: 48.00%
# Round: 8. Client: 12 (mobilenetv2). Epoch: 2. Loss: 0.427. Train accuracy: 49.65%. Test accuracy: 51.40%
# Round: 8. Client: 12 (mobilenetv2). Epoch: 3. Loss: 0.381. Train accuracy: 56.15%. Test accuracy: 51.20%
# Round: 8. Client: 12 (mobilenetv2). Epoch: 4. Loss: 0.375. Train accuracy: 55.50%. Test accuracy: 51.00%
# Round: 8. Client: 12 (mobilenetv2). Epoch: 5. Loss: 0.368. Train accuracy: 58.05%. Test accuracy: 51.60%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.122. Train accuracy: 56.38%. Test accuracy: 57.64%
# KT: simple_cnn. Epoch: 2. Loss: 0.079. Train accuracy: 56.66%. Test accuracy: 56.36%
# KT: simple_cnn. Epoch: 3. Loss: 0.039. Train accuracy: 57.79%. Test accuracy: 58.29%
# KT: simple_cnn. Epoch: 4. Loss: 0.028. Train accuracy: 58.07%. Test accuracy: 58.50%
# KT: simple_cnn. Epoch: 5. Loss: 0.024. Train accuracy: 57.98%. Test accuracy: 58.43%
# KT: simple_cnn. Epoch: 6. Loss: 0.024. Train accuracy: 58.09%. Test accuracy: 58.36%
# KT: simple_cnn. Epoch: 7. Loss: 0.023. Train accuracy: 58.07%. Test accuracy: 58.36%
# KT: simple_cnn. Epoch: 8. Loss: 0.023. Train accuracy: 58.00%. Test accuracy: 58.29%
# KT: simple_cnn. Epoch: 9. Loss: 0.023. Train accuracy: 58.05%. Test accuracy: 58.21%
# KT: simple_cnn. Epoch: 10. Loss: 0.023. Train accuracy: 58.07%. Test accuracy: 58.21%
# KT: resnet. Epoch: 1. Loss: 0.156. Train accuracy: 55.46%. Test accuracy: 59.00%
# KT: resnet. Epoch: 2. Loss: 0.104. Train accuracy: 56.75%. Test accuracy: 58.86%
# KT: resnet. Epoch: 3. Loss: 0.105. Train accuracy: 56.41%. Test accuracy: 59.00%
# KT: resnet. Epoch: 4. Loss: 0.101. Train accuracy: 56.30%. Test accuracy: 58.71%
# KT: resnet. Epoch: 5. Loss: 0.097. Train accuracy: 56.54%. Test accuracy: 59.07%
# KT: resnet. Epoch: 6. Loss: 0.094. Train accuracy: 56.73%. Test accuracy: 58.71%
# KT: resnet. Epoch: 7. Loss: 0.091. Train accuracy: 56.77%. Test accuracy: 58.71%
# KT: resnet. Epoch: 8. Loss: 0.089. Train accuracy: 56.80%. Test accuracy: 59.07%
# KT: resnet. Epoch: 9. Loss: 0.088. Train accuracy: 56.80%. Test accuracy: 59.21%
# KT: resnet. Epoch: 10. Loss: 0.086. Train accuracy: 56.86%. Test accuracy: 59.14%
# KT: mobilenetv2. Epoch: 1. Loss: 0.274. Train accuracy: 50.89%. Test accuracy: 51.93%
# KT: mobilenetv2. Epoch: 2. Loss: 0.155. Train accuracy: 52.75%. Test accuracy: 52.71%
# KT: mobilenetv2. Epoch: 3. Loss: 0.122. Train accuracy: 53.41%. Test accuracy: 53.57%
# KT: mobilenetv2. Epoch: 4. Loss: 0.117. Train accuracy: 53.36%. Test accuracy: 53.50%
# KT: mobilenetv2. Epoch: 5. Loss: 0.113. Train accuracy: 53.32%. Test accuracy: 53.07%
# KT: mobilenetv2. Epoch: 6. Loss: 0.112. Train accuracy: 53.23%. Test accuracy: 53.07%
# KT: mobilenetv2. Epoch: 7. Loss: 0.112. Train accuracy: 53.41%. Test accuracy: 53.07%
# KT: mobilenetv2. Epoch: 8. Loss: 0.112. Train accuracy: 53.41%. Test accuracy: 53.00%
# KT: mobilenetv2. Epoch: 9. Loss: 0.111. Train accuracy: 53.48%. Test accuracy: 53.00%
# KT: mobilenetv2. Epoch: 10. Loss: 0.111. Train accuracy: 53.48%. Test accuracy: 53.07%
# Accuracy of simple_cnn on the 3000 test images at 8 round: 57.86666666666667 %
# Accuracy of resnet on the 3000 test images at 8 round: 57.8 %
# Accuracy of mobilenetv2 on the 3000 test images at 8 round: 53.13333333333333 %
# Model ../storage/model/feddf/model_server_simple_cnn_8.pt saved
# Model ../storage/model/feddf/model_server_resnet_8.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_8.pt saved
# Chosen clients: [1, 11, 6]
# Round: 9. Client: 1 (resnet). Epoch: 1. Loss: 0.405. Train accuracy: 54.15%. Test accuracy: 52.40%
# Round: 9. Client: 1 (resnet). Epoch: 2. Loss: 0.375. Train accuracy: 56.95%. Test accuracy: 52.40%
# Round: 9. Client: 1 (resnet). Epoch: 3. Loss: 0.366. Train accuracy: 57.25%. Test accuracy: 53.40%
# Round: 9. Client: 1 (resnet). Epoch: 4. Loss: 0.355. Train accuracy: 59.55%. Test accuracy: 52.60%
# Round: 9. Client: 1 (resnet). Epoch: 5. Loss: 0.346. Train accuracy: 60.60%. Test accuracy: 53.20%
# Round: 9. Client: 11 (simple_cnn). Epoch: 1. Loss: 0.425. Train accuracy: 51.40%. Test accuracy: 52.80%
# Round: 9. Client: 11 (simple_cnn). Epoch: 2. Loss: 0.330. Train accuracy: 60.85%. Test accuracy: 54.00%
# Round: 9. Client: 11 (simple_cnn). Epoch: 3. Loss: 0.256. Train accuracy: 69.50%. Test accuracy: 62.00%
# Round: 9. Client: 11 (simple_cnn). Epoch: 4. Loss: 0.222. Train accuracy: 75.00%. Test accuracy: 63.00%
# Round: 9. Client: 11 (simple_cnn). Epoch: 5. Loss: 0.203. Train accuracy: 78.20%. Test accuracy: 61.60%
# Round: 9. Client: 6 (mobilenetv2). Epoch: 1. Loss: 0.450. Train accuracy: 47.90%. Test accuracy: 49.40%
# Round: 9. Client: 6 (mobilenetv2). Epoch: 2. Loss: 0.414. Train accuracy: 52.30%. Test accuracy: 50.20%
# Round: 9. Client: 6 (mobilenetv2). Epoch: 3. Loss: 0.381. Train accuracy: 55.50%. Test accuracy: 52.40%
# Round: 9. Client: 6 (mobilenetv2). Epoch: 4. Loss: 0.367. Train accuracy: 57.30%. Test accuracy: 53.00%
# Round: 9. Client: 6 (mobilenetv2). Epoch: 5. Loss: 0.360. Train accuracy: 58.20%. Test accuracy: 53.80%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.117. Train accuracy: 57.23%. Test accuracy: 57.86%
# KT: simple_cnn. Epoch: 2. Loss: 0.057. Train accuracy: 58.43%. Test accuracy: 58.64%
# KT: simple_cnn. Epoch: 3. Loss: 0.037. Train accuracy: 59.23%. Test accuracy: 60.07%
# KT: simple_cnn. Epoch: 4. Loss: 0.027. Train accuracy: 59.39%. Test accuracy: 60.21%
# KT: simple_cnn. Epoch: 5. Loss: 0.023. Train accuracy: 59.68%. Test accuracy: 60.50%
# KT: simple_cnn. Epoch: 6. Loss: 0.023. Train accuracy: 59.61%. Test accuracy: 60.36%
# KT: simple_cnn. Epoch: 7. Loss: 0.022. Train accuracy: 59.46%. Test accuracy: 60.36%
# KT: simple_cnn. Epoch: 8. Loss: 0.022. Train accuracy: 59.59%. Test accuracy: 60.36%
# KT: simple_cnn. Epoch: 9. Loss: 0.022. Train accuracy: 59.55%. Test accuracy: 60.36%
# KT: simple_cnn. Epoch: 10. Loss: 0.022. Train accuracy: 59.57%. Test accuracy: 60.36%
# KT: resnet. Epoch: 1. Loss: 0.107. Train accuracy: 56.57%. Test accuracy: 59.57%
# KT: resnet. Epoch: 2. Loss: 0.073. Train accuracy: 57.50%. Test accuracy: 58.50%
# KT: resnet. Epoch: 3. Loss: 0.069. Train accuracy: 56.98%. Test accuracy: 58.07%
# KT: resnet. Epoch: 4. Loss: 0.067. Train accuracy: 57.11%. Test accuracy: 57.86%
# KT: resnet. Epoch: 5. Loss: 0.065. Train accuracy: 57.18%. Test accuracy: 57.86%
# KT: resnet. Epoch: 6. Loss: 0.062. Train accuracy: 57.30%. Test accuracy: 57.71%
# KT: resnet. Epoch: 7. Loss: 0.061. Train accuracy: 57.38%. Test accuracy: 58.07%
# KT: resnet. Epoch: 8. Loss: 0.059. Train accuracy: 57.41%. Test accuracy: 58.14%
# KT: resnet. Epoch: 9. Loss: 0.058. Train accuracy: 57.52%. Test accuracy: 58.43%
# KT: resnet. Epoch: 10. Loss: 0.057. Train accuracy: 57.54%. Test accuracy: 58.21%
# KT: mobilenetv2. Epoch: 1. Loss: 0.243. Train accuracy: 50.79%. Test accuracy: 53.43%
# KT: mobilenetv2. Epoch: 2. Loss: 0.107. Train accuracy: 53.95%. Test accuracy: 54.21%
# KT: mobilenetv2. Epoch: 3. Loss: 0.087. Train accuracy: 54.43%. Test accuracy: 54.57%
# KT: mobilenetv2. Epoch: 4. Loss: 0.083. Train accuracy: 54.73%. Test accuracy: 54.36%
# KT: mobilenetv2. Epoch: 5. Loss: 0.080. Train accuracy: 54.57%. Test accuracy: 54.50%
# KT: mobilenetv2. Epoch: 6. Loss: 0.080. Train accuracy: 54.62%. Test accuracy: 54.50%
# KT: mobilenetv2. Epoch: 7. Loss: 0.079. Train accuracy: 54.70%. Test accuracy: 54.50%
# KT: mobilenetv2. Epoch: 8. Loss: 0.079. Train accuracy: 54.70%. Test accuracy: 54.57%
# KT: mobilenetv2. Epoch: 9. Loss: 0.079. Train accuracy: 54.68%. Test accuracy: 54.57%
# KT: mobilenetv2. Epoch: 10. Loss: 0.079. Train accuracy: 54.66%. Test accuracy: 54.57%
# Accuracy of simple_cnn on the 3000 test images at 9 round: 58.833333333333336 %
# Accuracy of resnet on the 3000 test images at 9 round: 57.8 %
# Accuracy of mobilenetv2 on the 3000 test images at 9 round: 54.5 %
# Model ../storage/model/feddf/model_server_simple_cnn_9.pt saved
# Model ../storage/model/feddf/model_server_resnet_9.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_9.pt saved
# Chosen clients: [1, 17, 12]
# Round: 10. Client: 1 (resnet). Epoch: 1. Loss: 0.379. Train accuracy: 56.10%. Test accuracy: 55.00%
# Round: 10. Client: 1 (resnet). Epoch: 2. Loss: 0.351. Train accuracy: 59.90%. Test accuracy: 53.20%
# Round: 10. Client: 1 (resnet). Epoch: 3. Loss: 0.342. Train accuracy: 61.15%. Test accuracy: 54.20%
# Round: 10. Client: 1 (resnet). Epoch: 4. Loss: 0.335. Train accuracy: 61.70%. Test accuracy: 55.20%
# Round: 10. Client: 1 (resnet). Epoch: 5. Loss: 0.328. Train accuracy: 62.60%. Test accuracy: 55.20%
# Round: 10. Client: 17 (simple_cnn). Epoch: 1. Loss: 0.323. Train accuracy: 62.85%. Test accuracy: 54.20%
# Round: 10. Client: 17 (simple_cnn). Epoch: 2. Loss: 0.224. Train accuracy: 75.00%. Test accuracy: 52.60%
# Round: 10. Client: 17 (simple_cnn). Epoch: 3. Loss: 0.164. Train accuracy: 81.60%. Test accuracy: 59.20%
# Round: 10. Client: 17 (simple_cnn). Epoch: 4. Loss: 0.125. Train accuracy: 87.60%. Test accuracy: 61.40%
# Round: 10. Client: 17 (simple_cnn). Epoch: 5. Loss: 0.110. Train accuracy: 89.55%. Test accuracy: 61.20%
# Round: 10. Client: 12 (mobilenetv2). Epoch: 1. Loss: 0.429. Train accuracy: 50.20%. Test accuracy: 51.00%
# Round: 10. Client: 12 (mobilenetv2). Epoch: 2. Loss: 0.394. Train accuracy: 53.60%. Test accuracy: 52.20%
# Round: 10. Client: 12 (mobilenetv2). Epoch: 3. Loss: 0.355. Train accuracy: 58.05%. Test accuracy: 53.00%
# Round: 10. Client: 12 (mobilenetv2). Epoch: 4. Loss: 0.348. Train accuracy: 58.75%. Test accuracy: 53.80%
# Round: 10. Client: 12 (mobilenetv2). Epoch: 5. Loss: 0.341. Train accuracy: 59.70%. Test accuracy: 54.00%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.136. Train accuracy: 59.25%. Test accuracy: 59.07%
# KT: simple_cnn. Epoch: 2. Loss: 0.076. Train accuracy: 59.88%. Test accuracy: 59.79%
# KT: simple_cnn. Epoch: 3. Loss: 0.046. Train accuracy: 60.96%. Test accuracy: 60.50%
# KT: simple_cnn. Epoch: 4. Loss: 0.032. Train accuracy: 61.07%. Test accuracy: 60.43%
# KT: simple_cnn. Epoch: 5. Loss: 0.027. Train accuracy: 61.12%. Test accuracy: 60.21%
# KT: simple_cnn. Epoch: 6. Loss: 0.026. Train accuracy: 61.07%. Test accuracy: 60.29%
# KT: simple_cnn. Epoch: 7. Loss: 0.026. Train accuracy: 61.09%. Test accuracy: 60.57%
# KT: simple_cnn. Epoch: 8. Loss: 0.025. Train accuracy: 61.09%. Test accuracy: 60.43%
# KT: simple_cnn. Epoch: 9. Loss: 0.025. Train accuracy: 61.12%. Test accuracy: 60.43%
# KT: simple_cnn. Epoch: 10. Loss: 0.025. Train accuracy: 61.12%. Test accuracy: 60.36%
# KT: resnet. Epoch: 1. Loss: 0.155. Train accuracy: 57.66%. Test accuracy: 59.71%
# KT: resnet. Epoch: 2. Loss: 0.117. Train accuracy: 58.32%. Test accuracy: 59.79%
# KT: resnet. Epoch: 3. Loss: 0.117. Train accuracy: 58.48%. Test accuracy: 60.50%
# KT: resnet. Epoch: 4. Loss: 0.112. Train accuracy: 58.27%. Test accuracy: 60.29%
# KT: resnet. Epoch: 5. Loss: 0.108. Train accuracy: 58.30%. Test accuracy: 60.29%
# KT: resnet. Epoch: 6. Loss: 0.105. Train accuracy: 58.30%. Test accuracy: 60.14%
# KT: resnet. Epoch: 7. Loss: 0.104. Train accuracy: 58.27%. Test accuracy: 60.29%
# KT: resnet. Epoch: 8. Loss: 0.102. Train accuracy: 58.30%. Test accuracy: 60.43%
# KT: resnet. Epoch: 9. Loss: 0.100. Train accuracy: 58.43%. Test accuracy: 60.14%
# KT: resnet. Epoch: 10. Loss: 0.099. Train accuracy: 58.57%. Test accuracy: 60.07%
# KT: mobilenetv2. Epoch: 1. Loss: 0.253. Train accuracy: 53.14%. Test accuracy: 53.64%
# KT: mobilenetv2. Epoch: 2. Loss: 0.174. Train accuracy: 54.38%. Test accuracy: 54.00%
# KT: mobilenetv2. Epoch: 3. Loss: 0.134. Train accuracy: 55.64%. Test accuracy: 55.79%
# KT: mobilenetv2. Epoch: 4. Loss: 0.126. Train accuracy: 55.61%. Test accuracy: 55.57%
# KT: mobilenetv2. Epoch: 5. Loss: 0.122. Train accuracy: 55.75%. Test accuracy: 55.64%
# KT: mobilenetv2. Epoch: 6. Loss: 0.121. Train accuracy: 55.84%. Test accuracy: 55.50%
# KT: mobilenetv2. Epoch: 7. Loss: 0.120. Train accuracy: 55.96%. Test accuracy: 55.57%
# KT: mobilenetv2. Epoch: 8. Loss: 0.120. Train accuracy: 55.95%. Test accuracy: 55.50%
# KT: mobilenetv2. Epoch: 9. Loss: 0.120. Train accuracy: 55.93%. Test accuracy: 55.50%
# KT: mobilenetv2. Epoch: 10. Loss: 0.120. Train accuracy: 55.93%. Test accuracy: 55.50%
# Accuracy of simple_cnn on the 3000 test images at 10 round: 59.96666666666667 %
# Accuracy of resnet on the 3000 test images at 10 round: 59.36666666666667 %
# Accuracy of mobilenetv2 on the 3000 test images at 10 round: 55.4 %
# Model ../storage/model/feddf/model_server_simple_cnn_10.pt saved
# Model ../storage/model/feddf/model_server_resnet_10.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_10.pt saved
# Chosen clients: [16, 14, 18]
# Round: 11. Client: 16 (resnet). Epoch: 1. Loss: 0.384. Train accuracy: 56.60%. Test accuracy: 54.00%
# Round: 11. Client: 16 (resnet). Epoch: 2. Loss: 0.362. Train accuracy: 59.15%. Test accuracy: 57.60%
# Round: 11. Client: 16 (resnet). Epoch: 3. Loss: 0.343. Train accuracy: 61.35%. Test accuracy: 58.80%
# Round: 11. Client: 16 (resnet). Epoch: 4. Loss: 0.333. Train accuracy: 62.35%. Test accuracy: 59.60%
# Round: 11. Client: 16 (resnet). Epoch: 5. Loss: 0.324. Train accuracy: 63.35%. Test accuracy: 60.20%
# Round: 11. Client: 14 (simple_cnn). Epoch: 1. Loss: 0.419. Train accuracy: 53.75%. Test accuracy: 55.60%
# Round: 11. Client: 14 (simple_cnn). Epoch: 2. Loss: 0.310. Train accuracy: 64.70%. Test accuracy: 56.00%
# ...
# Round: 38. Client: 19 (resnet). Epoch: 4. Loss: 0.247. Train accuracy: 70.95%. Test accuracy: 63.80%
# Round: 38. Client: 19 (resnet). Epoch: 5. Loss: 0.236. Train accuracy: 72.95%. Test accuracy: 63.80%
# Round: 38. Client: 17 (simple_cnn). Epoch: 1. Loss: 0.288. Train accuracy: 67.25%. Test accuracy: 67.60%
# Round: 38. Client: 17 (simple_cnn). Epoch: 2. Loss: 0.182. Train accuracy: 81.00%. Test accuracy: 67.60%
# Round: 38. Client: 17 (simple_cnn). Epoch: 3. Loss: 0.124. Train accuracy: 86.45%. Test accuracy: 70.40%
# Round: 38. Client: 17 (simple_cnn). Epoch: 4. Loss: 0.105. Train accuracy: 89.85%. Test accuracy: 70.80%
# Round: 38. Client: 17 (simple_cnn). Epoch: 5. Loss: 0.094. Train accuracy: 90.85%. Test accuracy: 70.40%
# Round: 38. Client: 12 (mobilenetv2). Epoch: 1. Loss: 0.298. Train accuracy: 66.60%. Test accuracy: 63.80%
# Round: 38. Client: 12 (mobilenetv2). Epoch: 2. Loss: 0.272. Train accuracy: 68.30%. Test accuracy: 64.40%
# Round: 38. Client: 12 (mobilenetv2). Epoch: 3. Loss: 0.241. Train accuracy: 72.65%. Test accuracy: 68.40%
# Round: 38. Client: 12 (mobilenetv2). Epoch: 4. Loss: 0.233. Train accuracy: 73.45%. Test accuracy: 67.80%
# Round: 38. Client: 12 (mobilenetv2). Epoch: 5. Loss: 0.227. Train accuracy: 74.35%. Test accuracy: 67.80%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.097. Train accuracy: 68.73%. Test accuracy: 67.50%
# KT: simple_cnn. Epoch: 2. Loss: 0.106. Train accuracy: 67.95%. Test accuracy: 67.86%
# KT: simple_cnn. Epoch: 3. Loss: 0.066. Train accuracy: 68.73%. Test accuracy: 68.29%
# KT: simple_cnn. Epoch: 4. Loss: 0.046. Train accuracy: 69.12%. Test accuracy: 68.21%
# KT: simple_cnn. Epoch: 5. Loss: 0.037. Train accuracy: 69.46%. Test accuracy: 68.29%
# KT: simple_cnn. Epoch: 6. Loss: 0.036. Train accuracy: 69.45%. Test accuracy: 68.36%
# KT: simple_cnn. Epoch: 7. Loss: 0.035. Train accuracy: 69.45%. Test accuracy: 68.36%
# KT: simple_cnn. Epoch: 8. Loss: 0.035. Train accuracy: 69.43%. Test accuracy: 68.36%
# KT: simple_cnn. Epoch: 9. Loss: 0.035. Train accuracy: 69.46%. Test accuracy: 68.36%
# KT: simple_cnn. Epoch: 10. Loss: 0.034. Train accuracy: 69.45%. Test accuracy: 68.36%
# KT: resnet. Epoch: 1. Loss: 0.115. Train accuracy: 68.38%. Test accuracy: 68.00%
# KT: resnet. Epoch: 2. Loss: 0.080. Train accuracy: 68.41%. Test accuracy: 67.93%
# KT: resnet. Epoch: 3. Loss: 0.073. Train accuracy: 68.21%. Test accuracy: 67.71%
# KT: resnet. Epoch: 4. Loss: 0.070. Train accuracy: 68.39%. Test accuracy: 68.00%
# KT: resnet. Epoch: 5. Loss: 0.068. Train accuracy: 68.30%. Test accuracy: 67.86%
# KT: resnet. Epoch: 6. Loss: 0.066. Train accuracy: 68.64%. Test accuracy: 67.86%
# KT: resnet. Epoch: 7. Loss: 0.065. Train accuracy: 68.62%. Test accuracy: 68.00%
# KT: resnet. Epoch: 8. Loss: 0.064. Train accuracy: 68.75%. Test accuracy: 68.07%
# KT: resnet. Epoch: 9. Loss: 0.063. Train accuracy: 68.82%. Test accuracy: 68.29%
# KT: resnet. Epoch: 10. Loss: 0.063. Train accuracy: 68.73%. Test accuracy: 68.07%
# KT: mobilenetv2. Epoch: 1. Loss: 0.151. Train accuracy: 66.55%. Test accuracy: 65.00%
# KT: mobilenetv2. Epoch: 2. Loss: 0.112. Train accuracy: 67.46%. Test accuracy: 64.86%
# KT: mobilenetv2. Epoch: 3. Loss: 0.082. Train accuracy: 67.21%. Test accuracy: 65.86%
# KT: mobilenetv2. Epoch: 4. Loss: 0.080. Train accuracy: 67.30%. Test accuracy: 65.79%
# KT: mobilenetv2. Epoch: 5. Loss: 0.076. Train accuracy: 67.52%. Test accuracy: 65.64%
# KT: mobilenetv2. Epoch: 6. Loss: 0.075. Train accuracy: 67.50%. Test accuracy: 65.71%
# KT: mobilenetv2. Epoch: 7. Loss: 0.074. Train accuracy: 67.46%. Test accuracy: 65.93%
# KT: mobilenetv2. Epoch: 8. Loss: 0.074. Train accuracy: 67.55%. Test accuracy: 65.86%
# KT: mobilenetv2. Epoch: 9. Loss: 0.074. Train accuracy: 67.54%. Test accuracy: 65.86%
# KT: mobilenetv2. Epoch: 10. Loss: 0.074. Train accuracy: 67.54%. Test accuracy: 65.86%
# Accuracy of simple_cnn on the 3000 test images at 38 round: 68.26666666666667 %
# Accuracy of resnet on the 3000 test images at 38 round: 67.9 %
# Accuracy of mobilenetv2 on the 3000 test images at 38 round: 66.03333333333333 %
# Model ../storage/model/feddf/model_server_simple_cnn_38.pt saved
# Model ../storage/model/feddf/model_server_resnet_38.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_38.pt saved
# Chosen clients: [16, 8, 9]
# Round: 39. Client: 16 (resnet). Epoch: 1. Loss: 0.319. Train accuracy: 64.80%. Test accuracy: 65.80%
# Round: 39. Client: 16 (resnet). Epoch: 2. Loss: 0.281. Train accuracy: 68.80%. Test accuracy: 67.40%
# Round: 39. Client: 16 (resnet). Epoch: 3. Loss: 0.267. Train accuracy: 71.20%. Test accuracy: 68.20%
# Round: 39. Client: 16 (resnet). Epoch: 4. Loss: 0.255. Train accuracy: 72.10%. Test accuracy: 68.40%
# Round: 39. Client: 16 (resnet). Epoch: 5. Loss: 0.244. Train accuracy: 72.45%. Test accuracy: 67.80%
# Round: 39. Client: 8 (simple_cnn). Epoch: 1. Loss: 0.247. Train accuracy: 72.50%. Test accuracy: 67.00%
# Round: 39. Client: 8 (simple_cnn). Epoch: 2. Loss: 0.152. Train accuracy: 84.50%. Test accuracy: 66.40%
# Round: 39. Client: 8 (simple_cnn). Epoch: 3. Loss: 0.095. Train accuracy: 90.50%. Test accuracy: 65.60%
# Round: 39. Client: 8 (simple_cnn). Epoch: 4. Loss: 0.081. Train accuracy: 92.60%. Test accuracy: 66.40%
# Round: 39. Client: 8 (simple_cnn). Epoch: 5. Loss: 0.071. Train accuracy: 93.95%. Test accuracy: 66.60%
# Round: 39. Client: 9 (mobilenetv2). Epoch: 1. Loss: 0.329. Train accuracy: 63.15%. Test accuracy: 61.60%
# Round: 39. Client: 9 (mobilenetv2). Epoch: 2. Loss: 0.304. Train accuracy: 65.65%. Test accuracy: 64.20%
# Round: 39. Client: 9 (mobilenetv2). Epoch: 3. Loss: 0.268. Train accuracy: 69.40%. Test accuracy: 65.00%
# Round: 39. Client: 9 (mobilenetv2). Epoch: 4. Loss: 0.256. Train accuracy: 70.70%. Test accuracy: 66.60%
# Round: 39. Client: 9 (mobilenetv2). Epoch: 5. Loss: 0.249. Train accuracy: 71.55%. Test accuracy: 66.60%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.108. Train accuracy: 68.54%. Test accuracy: 68.57%
# KT: simple_cnn. Epoch: 2. Loss: 0.137. Train accuracy: 67.91%. Test accuracy: 66.50%
# KT: simple_cnn. Epoch: 3. Loss: 0.076. Train accuracy: 68.89%. Test accuracy: 68.93%
# KT: simple_cnn. Epoch: 4. Loss: 0.050. Train accuracy: 69.12%. Test accuracy: 69.00%
# KT: simple_cnn. Epoch: 5. Loss: 0.040. Train accuracy: 69.11%. Test accuracy: 69.00%
# KT: simple_cnn. Epoch: 6. Loss: 0.039. Train accuracy: 68.89%. Test accuracy: 68.93%
# KT: simple_cnn. Epoch: 7. Loss: 0.038. Train accuracy: 68.96%. Test accuracy: 68.93%
# KT: simple_cnn. Epoch: 8. Loss: 0.038. Train accuracy: 68.98%. Test accuracy: 68.79%
# KT: simple_cnn. Epoch: 9. Loss: 0.038. Train accuracy: 68.98%. Test accuracy: 68.79%
# KT: simple_cnn. Epoch: 10. Loss: 0.038. Train accuracy: 68.98%. Test accuracy: 68.71%
# KT: resnet. Epoch: 1. Loss: 0.131. Train accuracy: 68.43%. Test accuracy: 68.00%
# KT: resnet. Epoch: 2. Loss: 0.091. Train accuracy: 68.55%. Test accuracy: 68.29%
# KT: resnet. Epoch: 3. Loss: 0.084. Train accuracy: 68.46%. Test accuracy: 68.64%
# KT: resnet. Epoch: 4. Loss: 0.079. Train accuracy: 68.48%. Test accuracy: 68.79%
# KT: resnet. Epoch: 5. Loss: 0.075. Train accuracy: 68.43%. Test accuracy: 68.64%
# KT: resnet. Epoch: 6. Loss: 0.072. Train accuracy: 68.46%. Test accuracy: 68.43%
# KT: resnet. Epoch: 7. Loss: 0.070. Train accuracy: 68.50%. Test accuracy: 68.43%
# KT: resnet. Epoch: 8. Loss: 0.068. Train accuracy: 68.52%. Test accuracy: 68.00%
# KT: resnet. Epoch: 9. Loss: 0.066. Train accuracy: 68.61%. Test accuracy: 68.14%
# KT: resnet. Epoch: 10. Loss: 0.065. Train accuracy: 68.48%. Test accuracy: 68.14%
# KT: mobilenetv2. Epoch: 1. Loss: 0.164. Train accuracy: 66.59%. Test accuracy: 65.36%
# KT: mobilenetv2. Epoch: 2. Loss: 0.126. Train accuracy: 67.73%. Test accuracy: 65.57%
# KT: mobilenetv2. Epoch: 3. Loss: 0.097. Train accuracy: 67.88%. Test accuracy: 66.43%
# KT: mobilenetv2. Epoch: 4. Loss: 0.092. Train accuracy: 67.79%. Test accuracy: 66.50%
# KT: mobilenetv2. Epoch: 5. Loss: 0.086. Train accuracy: 68.09%. Test accuracy: 67.21%
# KT: mobilenetv2. Epoch: 6. Loss: 0.086. Train accuracy: 68.16%. Test accuracy: 67.14%
# KT: mobilenetv2. Epoch: 7. Loss: 0.085. Train accuracy: 68.20%. Test accuracy: 67.14%
# KT: mobilenetv2. Epoch: 8. Loss: 0.085. Train accuracy: 68.20%. Test accuracy: 67.14%
# KT: mobilenetv2. Epoch: 9. Loss: 0.085. Train accuracy: 68.21%. Test accuracy: 67.14%
# KT: mobilenetv2. Epoch: 10. Loss: 0.085. Train accuracy: 68.21%. Test accuracy: 67.14%
# Accuracy of simple_cnn on the 3000 test images at 39 round: 68.33333333333333 %
# Accuracy of resnet on the 3000 test images at 39 round: 67.6 %
# Accuracy of mobilenetv2 on the 3000 test images at 39 round: 65.86666666666666 %
# Model ../storage/model/feddf/model_server_simple_cnn_39.pt saved
# Model ../storage/model/feddf/model_server_resnet_39.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_39.pt saved
# Chosen clients: [1, 5, 3]
# Round: 40. Client: 1 (resnet). Epoch: 1. Loss: 0.305. Train accuracy: 65.05%. Test accuracy: 64.80%
# Round: 40. Client: 1 (resnet). Epoch: 2. Loss: 0.273. Train accuracy: 68.60%. Test accuracy: 65.40%
# Round: 40. Client: 1 (resnet). Epoch: 3. Loss: 0.262. Train accuracy: 70.25%. Test accuracy: 64.80%
# Round: 40. Client: 1 (resnet). Epoch: 4. Loss: 0.252. Train accuracy: 71.25%. Test accuracy: 64.80%
# Round: 40. Client: 1 (resnet). Epoch: 5. Loss: 0.243. Train accuracy: 72.15%. Test accuracy: 63.80%
# Round: 40. Client: 5 (simple_cnn). Epoch: 1. Loss: 0.141. Train accuracy: 84.25%. Test accuracy: 62.80%
# Round: 40. Client: 5 (simple_cnn). Epoch: 2. Loss: 0.057. Train accuracy: 94.80%. Test accuracy: 64.60%
# Round: 40. Client: 5 (simple_cnn). Epoch: 3. Loss: 0.033. Train accuracy: 97.65%. Test accuracy: 65.80%
# Round: 40. Client: 5 (simple_cnn). Epoch: 4. Loss: 0.018. Train accuracy: 99.45%. Test accuracy: 65.80%
# Round: 40. Client: 5 (simple_cnn). Epoch: 5. Loss: 0.014. Train accuracy: 99.75%. Test accuracy: 66.20%
# Round: 40. Client: 3 (mobilenetv2). Epoch: 1. Loss: 0.321. Train accuracy: 64.40%. Test accuracy: 61.60%
# Round: 40. Client: 3 (mobilenetv2). Epoch: 2. Loss: 0.290. Train accuracy: 68.40%. Test accuracy: 60.80%
# Round: 40. Client: 3 (mobilenetv2). Epoch: 3. Loss: 0.262. Train accuracy: 71.10%. Test accuracy: 67.20%
# Round: 40. Client: 3 (mobilenetv2). Epoch: 4. Loss: 0.251. Train accuracy: 71.85%. Test accuracy: 68.20%
# Round: 40. Client: 3 (mobilenetv2). Epoch: 5. Loss: 0.245. Train accuracy: 72.40%. Test accuracy: 68.00%
# Models for simple_cnn are aggregated
# Models for resnet are aggregated
# Models for mobilenetv2 are aggregated
# KT: simple_cnn. Epoch: 1. Loss: 0.137. Train accuracy: 67.98%. Test accuracy: 66.29%
# KT: simple_cnn. Epoch: 2. Loss: 0.129. Train accuracy: 68.54%. Test accuracy: 67.64%
# KT: simple_cnn. Epoch: 3. Loss: 0.067. Train accuracy: 69.21%. Test accuracy: 67.57%
# KT: simple_cnn. Epoch: 4. Loss: 0.046. Train accuracy: 69.34%. Test accuracy: 67.93%
# KT: simple_cnn. Epoch: 5. Loss: 0.036. Train accuracy: 69.43%. Test accuracy: 68.00%
# KT: simple_cnn. Epoch: 6. Loss: 0.035. Train accuracy: 69.55%. Test accuracy: 68.00%
# KT: simple_cnn. Epoch: 7. Loss: 0.034. Train accuracy: 69.57%. Test accuracy: 68.07%
# KT: simple_cnn. Epoch: 8. Loss: 0.034. Train accuracy: 69.59%. Test accuracy: 68.07%
# KT: simple_cnn. Epoch: 9. Loss: 0.034. Train accuracy: 69.59%. Test accuracy: 68.07%
# KT: simple_cnn. Epoch: 10. Loss: 0.034. Train accuracy: 69.59%. Test accuracy: 68.07%
# KT: resnet. Epoch: 1. Loss: 0.193. Train accuracy: 67.88%. Test accuracy: 67.50%
# KT: resnet. Epoch: 2. Loss: 0.148. Train accuracy: 68.64%. Test accuracy: 67.64%
# KT: resnet. Epoch: 3. Loss: 0.136. Train accuracy: 68.73%. Test accuracy: 68.00%
# KT: resnet. Epoch: 4. Loss: 0.131. Train accuracy: 68.68%. Test accuracy: 67.71%
# KT: resnet. Epoch: 5. Loss: 0.128. Train accuracy: 68.93%. Test accuracy: 67.64%
# KT: resnet. Epoch: 6. Loss: 0.125. Train accuracy: 68.84%. Test accuracy: 67.64%
# KT: resnet. Epoch: 7. Loss: 0.124. Train accuracy: 68.77%. Test accuracy: 67.43%
# KT: resnet. Epoch: 8. Loss: 0.126. Train accuracy: 68.79%. Test accuracy: 67.86%
# KT: resnet. Epoch: 9. Loss: 0.128. Train accuracy: 68.45%. Test accuracy: 67.86%
# KT: resnet. Epoch: 10. Loss: 0.128. Train accuracy: 68.45%. Test accuracy: 67.71%
# KT: mobilenetv2. Epoch: 1. Loss: 0.223. Train accuracy: 67.29%. Test accuracy: 65.14%
# KT: mobilenetv2. Epoch: 2. Loss: 0.191. Train accuracy: 67.79%. Test accuracy: 65.57%
# KT: mobilenetv2. Epoch: 3. Loss: 0.143. Train accuracy: 67.91%. Test accuracy: 66.14%
# KT: mobilenetv2. Epoch: 4. Loss: 0.136. Train accuracy: 67.93%. Test accuracy: 66.21%
# KT: mobilenetv2. Epoch: 5. Loss: 0.126. Train accuracy: 68.12%. Test accuracy: 66.64%
# KT: mobilenetv2. Epoch: 6. Loss: 0.125. Train accuracy: 68.23%. Test accuracy: 66.43%
# KT: mobilenetv2. Epoch: 7. Loss: 0.124. Train accuracy: 68.25%. Test accuracy: 66.50%
# KT: mobilenetv2. Epoch: 8. Loss: 0.124. Train accuracy: 68.29%. Test accuracy: 66.50%
# KT: mobilenetv2. Epoch: 9. Loss: 0.124. Train accuracy: 68.25%. Test accuracy: 66.50%
# KT: mobilenetv2. Epoch: 10. Loss: 0.124. Train accuracy: 68.25%. Test accuracy: 66.50%
# Accuracy of simple_cnn on the 3000 test images at 40 round: 67.4 %
# Accuracy of resnet on the 3000 test images at 40 round: 67.43333333333334 %
# Accuracy of mobilenetv2 on the 3000 test images at 40 round: 66.76666666666667 %
# Model ../storage/model/feddf/model_server_simple_cnn_40.pt saved
# Model ../storage/model/feddf/model_server_resnet_40.pt saved
# Model ../storage/model/feddf/model_server_mobilenetv2_40.pt saved
# {'simple_cnn': {5: 40.8, 10: 45.03333333333333, 15: 47.46666666666667, 20: 50.4, 25: 52.6, 30: 54.5, 35: 55.233333333333334, 40: 57.86666666666667, 45: 58.833333333333336, 50: 59.96666666666667, 55: 61.2, 60: 60.86666666666667, 65: 62.9, 70: 63.53333333333333, 75: 63.5, 80: 64.03333333333333, 85: 64.4, 90: 63.96666666666667, 95: 64.6, 100: 65.63333333333334, 105: 65.73333333333333, 110: 66.06666666666666, 115: 66.5, 120: 66.73333333333333, 125: 66.66666666666667, 130: 66.86666666666666, 135: 66.83333333333333, 140: 67.6, 145: 66.9, 150: 67.16666666666667, 155: 67.46666666666667, 160: 68.06666666666666, 165: 66.33333333333333, 170: 66.5, 175: 67.43333333333334, 180: 67.03333333333333, 185: 68.06666666666666, 190: 68.26666666666667, 195: 68.33333333333333, 200: 67.4}, 'resnet': {5: 46.333333333333336, 10: 47.266666666666666, 15: 48.13333333333333, 20: 50.6, 25: 52.5, 30: 54.266666666666666, 35: 55.833333333333336, 40: 57.8, 45: 57.8, 50: 59.36666666666667, 55: 59.36666666666667, 60: 60.833333333333336, 65: 62.666666666666664, 70: 62.666666666666664, 75: 62.36666666666667, 80: 63.166666666666664, 85: 63.833333333333336, 90: 63.43333333333333, 95: 64.4, 100: 64.73333333333333, 105: 64.56666666666666, 110: 65.46666666666667, 115: 65.4, 120: 65.73333333333333, 125: 66.2, 130: 65.76666666666667, 135: 66.13333333333334, 140: 66.93333333333334, 145: 67.0, 150: 66.06666666666666, 155: 66.36666666666666, 160: 67.0, 165: 65.86666666666666, 170: 66.4, 175: 66.13333333333334, 180: 66.7, 185: 67.66666666666667, 190: 67.9, 195: 67.6, 200: 67.43333333333334}, 'mobilenetv2': {5: 44.2, 10: 43.43333333333333, 15: 43.36666666666667, 20: 46.53333333333333, 25: 48.6, 30: 50.833333333333336, 35: 51.6, 40: 53.13333333333333, 45: 54.5, 50: 55.4, 55: 56.766666666666666, 60: 57.833333333333336, 65: 59.1, 70: 58.766666666666666, 75: 60.166666666666664, 80: 61.266666666666666, 85: 60.7, 90: 61.56666666666667, 95: 62.46666666666667, 100: 62.733333333333334, 105: 62.5, 110: 62.56666666666667, 115: 63.3, 120: 64.26666666666667, 125: 63.86666666666667, 130: 64.0, 135: 64.43333333333334, 140: 65.3, 145: 63.733333333333334, 150: 64.53333333333333, 155: 64.93333333333334, 160: 65.16666666666667, 165: 65.13333333333334, 170: 65.73333333333333, 175: 65.13333333333334, 180: 65.83333333333333, 185: 66.23333333333333, 190: 66.03333333333333, 195: 65.86666666666666, 200: 66.76666666666667}}
